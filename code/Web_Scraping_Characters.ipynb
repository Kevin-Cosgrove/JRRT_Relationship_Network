# %% [markdown]
# ### Import required packages
# This notebook requires pandas and selenium packages to run

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

# %% [markdown]
# ### Create webdriver

# %%
#Initialize the Chrome driver with ChromeDriverManager
driver_service = Service(ChromeDriverManager().install())
options = webdriver.ChromeOptions()
#Add any additional options you need, for example:
#options.add_argument('--headless')  # Run Chrome in headless mode
#options.add_argument('--disable-gpu')  # Disable GPU acceleration
driver = webdriver.Chrome(service=driver_service, options=options)

# %% [markdown]
# ### Scrape book and character data from Tolkien wiki

# %%
#Go to wiki page for Tolkien universe
page_url = 'https://lotr.fandom.com/wiki/Category:Characters'
driver.get(page_url)

# %%
#Store each book wiki page to a unique variable
#Searching page_url by link text
hobbit_page = driver.find_element(By.LINK_TEXT, 'Category:The Hobbit characters')
lotr_page = driver.find_element(By.LINK_TEXT, 'Category:The Lord of the Rings characters')
silmarillion_page = driver.find_element(By.LINK_TEXT, 'Category:The Silmarillion characters')

# %%
#Store book character pages in a list for later looping
book_pages =[hobbit_page, lotr_page, silmarillion_page]

# %%
#Store meta data for the book character pages to a list of dictionaries
books=[]
for book in book_pages:
    book_url = book.get_attribute('href')
    book_name = book.text
    books.append({'book_name': book_name, 'url': book_url})

# %%
books
# Out:
# [{'book_name': 'Category:The Hobbit characters',
#   'url': 'https://lotr.fandom.com/wiki/Category:The_Hobbit_characters'},
#  {'book_name': 'Category:The Lord of the Rings characters',
#   'url': 'https://lotr.fandom.com/wiki/Category:The_Lord_of_the_Rings_characters'},
#  {'book_name': 'Category:The Silmarillion characters',
#   'url': 'https://lotr.fandom.com/wiki/Category:The_Silmarillion_characters'}]

# %%
#Store characters from each book to a list of dictionaries
characters_list = []


for book in books:
    driver.get(book['url'])
    character_elems = driver.find_elements(By.CLASS_NAME, 'category-page__member-link')
    for elem in character_elems:
        characters_list.append({'book': book['book_name'], 'character': elem.text})

# %%
#Close driver
driver.close()

# %%
#Quit driver
driver.quit()

# %%
characters_list
# Out:
# [{'book': 'Category:The Hobbit characters', 'character': 'Bilbo Baggins'},
#  {'book': 'Category:The Hobbit characters', 'character': 'Balin'},
#  {'book': 'Category:The Hobbit characters', 'character': 'Bard'},
#  {'book': 'Category:The Hobbit characters', 'character': 'Beorn'},
#  {'book': 'Category:The Hobbit characters', 'character': 'Bifur'},
#  {'book': 'Category:The Hobbit characters', 'character': 'Bladorthin'},
#  {'book': 'Category:The Hobbit characters', 'character': 'Bofur'},
#  {'book': 'Category:The Hobbit characters', 'character': 'Bolg'},
#  {'book': 'Category:The Hobbit characters', 'character': 'Bombur'},
#  {'book': 'Category:The Hobbit characters',
#   'character': 'Captain of the guard'},
#  {'book': 'Category:The Hobbit characters', 'character': 'Carc'},
#  {'book': 'Category:The Hobbit characters',
#   'character': 'Category:Characters that have appeared in the Hobbit and the Lord of the Rings'},
#  {'book': 'Category:The Hobbit characters',
#   'character': 'Chief of the guards (Woodland Realm)'},
#  {'book': 'Category:The Hobbit characters',
#   'character': 'Councilors (Lake-town)'},
#  {'book': 'Category:The Hobbit characters', 'character': 'Dori'},
#  {'book': 'Category:The Hobbit characters', 'character': 'Dwalin'},
#  {'book': 'Category:The Hobbit characters', 'character': 'Dáin II'},
#  {'book': 'Category:The Hobbit characters', 'character': 'Elrond'},
#  {'book': 'Category:The Hobbit characters', 'character': 'Fíli and Kíli'},
#  {'book': 'Category:The Hobbit characters', 'character': 'Galion'},
#  {'book': 'Category:The Hobbit characters', 'character': 'Gandalf'},
#  {'book': 'Category:The Hobbit characters', 'character': 'Glóin'},
#  {'book': 'Category:The Hobbit characters', 'character': 'Golfimbul'},
#  {'book': 'Category:The Hobbit characters', 'character': 'Gollum'},
#  {'book': 'Category:The Hobbit characters', 'character': 'Great Goblin'},
#  {'book': 'Category:The Hobbit characters',
#   'character': 'Great grey chief wolf'},
#  {'book': 'Category:The Hobbit characters',
#   'character': 'Master of Lake-town'},
#  {'book': 'Category:The Hobbit characters', 'character': 'Nori'},
#  {'book': 'Category:The Hobbit characters', 'character': 'Ori'},
#  {'book': 'Category:The Hobbit characters', 'character': 'Radagast'},
#  {'book': 'Category:The Hobbit characters', 'character': 'Roäc'},
#  {'book': 'Category:The Hobbit characters', 'character': 'Smaug'},
#  {'book': 'Category:The Hobbit characters', 'character': 'Thorin II'},
#  {'book': 'Category:The Hobbit characters', 'character': 'Thranduil'},
#  {'book': 'Category:The Hobbit characters', 'character': 'Thráin II'},
#  {'book': 'Category:The Hobbit characters', 'character': 'Thrór'},
#  {'book': 'Category:The Hobbit characters',
#   'character': 'Tom, Bert, and William'},
#  {'book': 'Category:The Hobbit characters', 'character': 'Bandobras Took'},
#  {'book': 'Category:The Hobbit characters', 'character': 'Óin'},
#  {'book': 'Category:The Lord of the Rings characters',
#   'character': 'Aragorn II'},
#  {'book': 'Category:The Lord of the Rings characters', 'character': 'Arwen'},
#  {'book': 'Category:The Lord of the Rings characters',
#   'character': 'Bilbo Baggins'},
#  {'book': 'Category:The Lord of the Rings characters',
#   'character': 'Frodo Baggins'},
#  {'book': 'Category:The Lord of the Rings characters',
#   'character': 'Beregond (Captain)'},
#  {'book': 'Category:The Lord of the Rings characters', 'character': 'Bergil'},
#  {'book': 'Category:The Lord of the Rings characters',
#   'character': 'Fredegar Bolger'},
#  {'book': 'Category:The Lord of the Rings characters',
#   'character': 'Tom Bombadil'},
#  {'book': 'Category:The Lord of the Rings characters', 'character': 'Boromir'},
#  {'book': 'Category:The Lord of the Rings characters',
#   'character': 'Meriadoc Brandybuck'},
#  {'book': 'Category:The Lord of the Rings characters',
#   'character': 'Barliman Butterbur'},
#  {'book': 'Category:The Lord of the Rings characters',
#   'character': 'Celeborn'},
#  {'book': 'Category:The Lord of the Rings characters',
#   'character': 'Category:Characters that have appeared in the Hobbit and the Lord of the Rings'},
#  {'book': 'Category:The Lord of the Rings characters',
#   'character': 'Denethor II'},
#  {'book': 'Category:The Lord of the Rings characters',
#   'character': 'Elladan and Elrohir'},
#  {'book': 'Category:The Lord of the Rings characters', 'character': 'Elrond'},
#  {'book': 'Category:The Lord of the Rings characters', 'character': 'Éomer'},
#  {'book': 'Category:The Lord of the Rings characters', 'character': 'Éowyn'},
#  {'book': 'Category:The Lord of the Rings characters', 'character': 'Faramir'},
#  {'book': 'Category:The Lord of the Rings characters',
#   'character': 'Galadriel'},
#  {'book': 'Category:The Lord of the Rings characters',
#   'character': 'Samwise Gamgee'},
#  {'book': 'Category:The Lord of the Rings characters', 'character': 'Gamling'},
#  {'book': 'Category:The Lord of the Rings characters', 'character': 'Gandalf'},
#  {'book': 'Category:The Lord of the Rings characters',
#   'character': 'Ghân-buri-Ghân'},
#  {'book': 'Category:The Lord of the Rings characters',
#   'character': 'Gildor Inglorion'},
#  {'book': 'Category:The Lord of the Rings characters', 'character': 'Gimli'},
#  {'book': 'Category:The Lord of the Rings characters',
#   'character': 'Glorfindel'},
#  {'book': 'Category:The Lord of the Rings characters',
#   'character': 'Goldberry'},
#  {'book': 'Category:The Lord of the Rings characters', 'character': 'Gollum'},
#  {'book': 'Category:The Lord of the Rings characters', 'character': 'Gorbag'},
#  {'book': 'Category:The Lord of the Rings characters',
#   'character': 'Grimbold'},
#  {'book': 'Category:The Lord of the Rings characters', 'character': 'Gwaihir'},
#  {'book': 'Category:The Lord of the Rings characters', 'character': 'Imrahil'},
#  {'book': 'Category:The Lord of the Rings characters', 'character': 'Legolas'},
#  {'book': 'Category:The Lord of the Rings characters', 'character': 'Lugdush'},
#  {'book': 'Category:The Lord of the Rings characters',
#   'character': 'Category:Major characters (The Lord of the Rings)'},
#  {'book': 'Category:The Lord of the Rings characters', 'character': 'Mauhúr'},
#  {'book': 'Category:The Lord of the Rings characters',
#   'character': 'Category:Minor characters (The Lord of the Rings)'},
#  {'book': 'Category:The Lord of the Rings characters', 'character': 'Saruman'},
#  {'book': 'Category:The Lord of the Rings characters', 'character': 'Shagrat'},
#  {'book': 'Category:The Lord of the Rings characters', 'character': 'Shelob'},
#  {'book': 'Category:The Lord of the Rings characters', 'character': 'Smaug'},
#  {'book': 'Category:The Lord of the Rings characters', 'character': 'Théoden'},
#  {'book': 'Category:The Lord of the Rings characters',
#   'character': 'Adelard Took'},
#  {'book': 'Category:The Lord of the Rings characters',
#   'character': 'Peregrin Took'},
#  {'book': 'Category:The Lord of the Rings characters',
#   'character': 'Treebeard'},
#  {'book': 'Category:The Lord of the Rings characters',
#   'character': 'Witch-king of Angmar'},
#  {'book': 'Category:The Lord of the Rings characters',
#   'character': "Witch-king's winged steed"},
#  {'book': 'Category:The Lord of the Rings characters', 'character': 'Gríma'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Aegnor'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Aerandir'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Aerin'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Aghan'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Amandil'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Amarië'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Amlach'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Amras'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Amrod'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Ancalagon'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Andreth'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Andróg'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Angrim'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Angrod'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Annael'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Ar-Gimilzôr'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Ar-Pharazôn'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Ar-Sakalthôr'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Aranwë'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Aratan'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Aratar'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Aredhel'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Arien'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Arthad'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Asgon'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Aulë'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Azaghâl'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Barach'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Baragund'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Barahir'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Baran'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Beleg'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Belegund'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Bereg'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Beren'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Borlach'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Borlad'},
#  {'book': 'Category:The Silmarillion characters',
#   'character': 'Boromir of Ladros'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Borthand'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Brandir'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Bregolas'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Bregor'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Brodda'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Bëor'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Bór'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Calmacil'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Caranthir'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Carcharoth'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Celebrimbor'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Celegorm'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Ciryon'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Curufin'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Círdan'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Daeron'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Dagnir'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Dairuin'},
#  {'book': 'Category:The Silmarillion characters',
#   'character': 'Denethor (First Age)'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Dior'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Dorlas'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Draugluin'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Durin I'},
#  {'book': 'Category:The Silmarillion characters',
#   'character': 'Ecthelion of the Fountain'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Eilinel'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Elatan'},
#  {'book': 'Category:The Silmarillion characters',
#   'character': 'Elemmírë (elf)'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Elendil'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Elendur'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Elenwë'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Elrond'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Elros'},
#  {'book': 'Category:The Silmarillion characters',
#   'character': 'Eluréd and Elurín'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Elwing'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Emeldir'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Erellont'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Estë'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Eärendil'},
#  {'book': 'Category:The Silmarillion characters',
#   'character': 'Eärendur of Andúnië'},
#  {'book': 'Category:The Silmarillion characters',
#   'character': 'Eärendur of Arnor'},
#  {'book': 'Category:The Silmarillion characters',
#   'character': 'Eärendur of Númenor'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Eärwen'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Eöl'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Eönwë'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Falathar'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Finarfin'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Finduilas'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Fingolfin'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Fingon'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Finrod'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Finwë'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Fuinur'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Fëanor'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Galadriel'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Galdor'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Gamil Zirak'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Gandalf'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Gelmir'},
#  {'book': 'Category:The Silmarillion characters',
#   'character': "Gelmir (of Angrod's kin)"},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Gil-galad'},
#  {'book': 'Category:The Silmarillion characters',
#   'character': 'Gildor (Edain)'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Gimilkhâd'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Glaurung'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Glirhuin'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Glorfindel'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Glóredhel'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Gorlim'},
#  {'book': 'Category:The Silmarillion characters',
#   'character': 'Gothmog (Balrog)'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Guilin'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Gundor'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Gwindor'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Hador'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Haldad'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Haldan'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Haldar'},
#  {'book': 'Category:The Silmarillion characters',
#   'character': 'Haldir (Chieftain of the Haladin)'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Haleth'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Halmir'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Handir'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Hareth'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Hathaldir'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Herumor'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Huan'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Hundad'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Hunthor'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Huor'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Húrin'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Ibûn'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Idril'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Ilmarë'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Eru Ilúvatar'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Imlach'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Indis'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Ingwë'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Inzilbêth'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Iorlas'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Isildur'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Khîm'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Lenwë'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Lorgan'},
#  {'book': 'Category:The Silmarillion characters',
#   'character': 'Lórien (Vala)'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Lúthien'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Mablung'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Maedhros'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Maeglin'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Maglor'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Mahtan'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Malach'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Mandos'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Manwë'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Marach'},
#  {'book': 'Category:The Silmarillion characters',
#   'character': 'Mardil Voronwë'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Melian'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Meneldil'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Morgoth'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Morwen'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Míriel'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Mîm'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Nerdanel'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Nessa'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Nienna'},
#  {'book': 'Category:The Silmarillion characters',
#   'character': 'Nimloth of Doriath'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Nimrodel'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Niënor'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Númendil'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Ohtar'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Olwë'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Orodreth'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Oromë'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Ossë'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Radhruin'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Ragnor'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Rían'},
#  {'book': 'Category:The Silmarillion characters',
#   'character': 'Rúmil (Noldo)'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Sador'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Saeros'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Salmar'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Sauron'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Soronto'},
#  {'book': 'Category:The Silmarillion characters',
#   'character': 'Tar-Ancalimon'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Tar-Ancalimë'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Tar-Atanamir'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Tar-Ciryatan'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Tar-Elendil'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Tar-Minastir'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Tar-Míriel'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Tar-Palantir'},
#  {'book': 'Category:The Silmarillion characters',
#   'character': 'Tar-Telemmaitë'},
#  {'book': 'Category:The Silmarillion characters',
#   'character': 'Tar-Vanimeldë'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Telchar'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Thingol'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Thorondor'},
#  {'book': 'Category:The Silmarillion characters',
#   'character': 'Thuringwethil'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Tilion'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Tulkas'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Tuor'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Turgon'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Túrin'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Uinen'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Uldor'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Ulfang'},
#  {'book': 'Category:The Silmarillion characters', 'character': 'Ulfast'}]

# %%
#Store character_list to a pandas dataframe
df = pd.DataFrame(characters_list)

# %%
#Save df to a pickle file for later use
df.to_pickle('characters.pkl')
