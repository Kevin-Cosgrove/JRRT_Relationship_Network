# %%
import pandas as pd
import numpy as np
import spacy
from spacy import displacy
import networkx as nx
import os
import re


import matplotlib.pyplot as plt

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB 1.3 MB/s eta 0:00:10
#      --------------------------------------- 0.1/12.8 MB 787.7 kB/s eta 0:00:17
#      ---------------------------------------- 0.1/12.8 MB 1.1 MB/s eta 0:00:12
#       --------------------------------------- 0.3/12.8 MB 1.7 MB/s eta 0:00:08
#      - -------------------------------------- 0.5/12.8 MB 2.2 MB/s eta 0:00:06
#      -- ------------------------------------- 0.7/12.8 MB 2.5 MB/s eta 0:00:05
#      -- ------------------------------------- 0.9/12.8 MB 3.0 MB/s eta 0:00:04
#      --- ------------------------------------ 1.2/12.8 MB 3.2 MB/s eta 0:00:04
#      ---- ----------------------------------- 1.4/12.8 MB 3.6 MB/s eta 0:00:04
#      ----- ---------------------------------- 1.7/12.8 MB 3.7 MB/s eta 0:00:04
#      ------ --------------------------------- 2.0/12.8 MB 3.9 MB/s eta 0:00:03
#      ------ --------------------------------- 2.2/12.8 MB 4.0 MB/s eta 0:00:03
#      ------- -------------------------------- 2.5/12.8 MB 4.3 MB/s eta 0:00:03
#      -------- ------------------------------- 2.8/12.8 MB 4.3 MB/s eta 0:00:03
#      --------- ------------------------------ 3.1/12.8 MB 4.5 MB/s eta 0:00:03
#      ---------- ----------------------------- 3.4/12.8 MB 4.7 MB/s eta 0:00:03
#      ----------- ---------------------------- 3.7/12.8 MB 4.7 MB/s eta 0:00:02
#      ------------ --------------------------- 3.9/12.8 MB 4.7 MB/s eta 0:00:02
#      ------------- -------------------------- 4.2/12.8 MB 4.8 MB/s eta 0:00:02
#      -------------- ------------------------- 4.6/12.8 MB 4.9 MB/s eta 0:00:02
#      -------------- ------------------------- 4.8/12.8 MB 4.9 MB/s eta 0:00:02
#      --------------- ------------------------ 5.1/12.8 MB 5.0 MB/s eta 0:00:02
#      ---------------- ----------------------- 5.3/12.8 MB 5.1 MB/s eta 0:00:02
#      ----------------- ---------------------- 5.6/12.8 MB 5.1 MB/s eta 0:00:02
#      ------------------ --------------------- 5.8/12.8 MB 5.1 MB/s eta 0:00:02
#      ------------------- -------------------- 6.2/12.8 MB 5.2 MB/s eta 0:00:02
#      -------------------- ------------------- 6.4/12.8 MB 5.2 MB/s eta 0:00:02
#      --------------------- ------------------ 6.7/12.8 MB 5.3 MB/s eta 0:00:02
#      ---------------------- ----------------- 7.1/12.8 MB 5.3 MB/s eta 0:00:02
#      ---------------------- ----------------- 7.4/12.8 MB 5.3 MB/s eta 0:00:02
#      ----------------------- ---------------- 7.6/12.8 MB 5.4 MB/s eta 0:00:01
#      ------------------------ --------------- 7.9/12.8 MB 5.4 MB/s eta 0:00:01
#      ------------------------- -------------- 8.3/12.8 MB 5.5 MB/s eta 0:00:01
#      -------------------------- ------------- 8.4/12.8 MB 5.4 MB/s eta 0:00:01
#      --------------------------- ------------ 8.7/12.8 MB 5.5 MB/s eta 0:00:01
#      ---------------------------- ----------- 9.0/12.8 MB 5.5 MB/s eta 0:00:01
#      ----------------------------- ---------- 9.3/12.8 MB 5.5 MB/s eta 0:00:01
#      ----------------------------- ---------- 9.6/12.8 MB 5.5 MB/s eta 0:00:01
#      ------------------------------ --------- 9.9/12.8 MB 5.5 MB/s eta 0:00:01
#      ------------------------------- -------- 10.2/12.8 MB 5.6 MB/s eta 0:00:01
#      -------------------------------- ------- 10.4/12.8 MB 5.9 MB/s eta 0:00:01
#      --------------------------------- ------ 10.7/12.8 MB 6.0 MB/s eta 0:00:01
#      ---------------------------------- ----- 11.0/12.8 MB 6.1 MB/s eta 0:00:01
#      ----------------------------------- ---- 11.2/12.8 MB 6.1 MB/s eta 0:00:01
#      ----------------------------------- ---- 11.5/12.8 MB 6.1 MB/s eta 0:00:01
#      ------------------------------------ --- 11.7/12.8 MB 6.1 MB/s eta 0:00:01
#      ------------------------------------- -- 12.0/12.8 MB 6.1 MB/s eta 0:00:01
#      -------------------------------------- - 12.2/12.8 MB 6.0 MB/s eta 0:00:01
#      ---------------------------------------  12.6/12.8 MB 6.1 MB/s eta 0:00:01
#      ---------------------------------------  12.8/12.8 MB 6.1 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\users\myxna\anaconda3\lib\site-packages (from en-core-web-sm==3.7.1) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\myxna\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\myxna\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\myxna\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\myxna\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\myxna\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\myxna\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\myxna\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\myxna\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\myxna\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\myxna\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\myxna\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\myxna\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\myxna\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\myxna\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\myxna\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.10.8)
# Requirement already satisfied: jinja2 in c:\users\myxna\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\myxna\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\myxna\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\myxna\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\myxna\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.24.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\myxna\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\myxna\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\myxna\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\myxna\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\myxna\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2023.11.17)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\myxna\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\myxna\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: colorama in c:\users\myxna\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\myxna\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\myxna\anaconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\myxna\anaconda3\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
#Load spacy's english language model
NER = spacy.load('en_core_web_sm')

# %%
books = [b for b in os.scandir('c:/users/myxna/desktop/datascienceprojects/lotr/data') if '.txt' in b.name]

# %%
books
# Out:
# [<DirEntry '00 - The Silmarillion.txt'>,
#  <DirEntry '01 - The Hobbit.txt'>,
#  <DirEntry '02 - The Lord of the Rings.txt'>]

# %%
book = books[1]
with open(book, 'r', encoding='utf-8') as file:
    book_text = file.read()
book_doc = NER(book_text)

# %%
displacy.render(book_doc[0:10000], style = 'ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     THE HOBBIT
#
#
# Seldom
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has a story been as widely praised as The <br>Hx)bbit. By parents, teachers, reviei^ers, and especially <br>by children themselves. Within
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a tew years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  its hero, <br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bilbo Baggins
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has taken his place among the ranks <br>of the immortals:
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Pooh, Toad. ... As with <br>all such classics enjoyment burgeons at each
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     succes¬
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  <br>sive reading, and grown-ups as much as children feel <br>the potency of its spell. <br><br>It is a tale of high adventure, undertaken by a <br>company of dwarves, in search of dragon-guarded <br>gold. A reluctant partner on this perilous quest is <br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bilbo Baggins
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , a comfort-loving, unambitious hobbit, <br>who surprises even himself by his resourcefulness <br>and skill as a burglar. <br><br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Encounters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  with giant spiders in the labyrinths <br>of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mirkwood
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and the evil goblins that live among <br>the roots of
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Misty Mountains
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , the palpitating <br>delicacy of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bilbo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# 's conversations with the dragon, <br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Smaug
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , and the grand climax in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Battle of the
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Five Armies
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# , are supremely exciting incidents. But <br>there are homelier moments too: good fellowship and <br>welcome meals along the road, laughter and song, <br>and all 'the freshness of an early world’. <br><br>The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hobbit
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is in itself a complete and marvellous <br>tale which may be read to the very young, or given <br>to children of any age to read for themselves. But it <br>is also a prelude to The Lord of the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rings
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , in which <br>the true significance of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bilbo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s success in riddles, and <br>the nature of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gollum’s 'Precious
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,* is revealed. <br><br>The books - and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  of all The Hobbit - speak of <br>the nobility and delight of life. They speak too of the <br>triumph of good over evil, and reaffirm our secret <br>hopes that, whatever the pdds, right will be victorious <br>over might. <br><br><br><br>by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     J. R. R. Tolkien
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  <br><br>The
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Adventures
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0

# %%
character_df = pd.read_pickle('characters.pkl')

# %%
character_df
# Out:
#                                      book      character
# 0          Category:The Hobbit characters  Bilbo Baggins
# 1          Category:The Hobbit characters          Balin
# 2          Category:The Hobbit characters           Bard
# 3          Category:The Hobbit characters          Beorn
# 4          Category:The Hobbit characters          Bifur
# ..                                    ...            ...
# 283  Category:The Silmarillion characters          Túrin
# 284  Category:The Silmarillion characters          Uinen
# 285  Category:The Silmarillion characters          Uldor
# 286  Category:The Silmarillion characters         Ulfang
# 287  Category:The Silmarillion characters         Ulfast
#
# [288 rows x 2 columns]
